# %%
# import the Python Image processing Library
from PIL import Image

# %%
# Create an Image object from an Image
img  = Image.open("testimage1.jpg")
x_size = img.size[0]
y_size = img.size[1]
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=491x368 at 0x1FF9F20BD30>

# %%
#  Image.crop(box=None)

#     Returns a rectangular region from this image. The box is a 4-tuple defining the left, upper, right, and lower pixel coordinate.

#     This is a lazy operation. Changes to the source image may or may not be reflected in the cropped image. To break the connection, call the load() method on the cropped copy.
#     Parameters:	box – The crop rectangle, as a (left, upper, right, lower)-tuple.
#     Return type:	Image
#     Returns:	An Image object.

# Crop the iceberg portion
cropped = imageObject.crop((0,100,x_size,y_size))
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=491x268 at 0x1FF9DDA4828>

# %%
imageObject.resize((x_size,y_size), Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=491x368 at 0x1FF9DDA40F0>
